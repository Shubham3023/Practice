# %%
import pandas as pd

# %%
df = pd.read_csv('sales_data_final.csv')

# %%
df.head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category              product_name sales quantity  \
# 0  Office Supplies      Storage       Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies  Acme Trimmer, High Speed   120        3
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# 1       0.1   36.036           9.72          Medium  2011
#
# [2 rows x 21 columns]

# %%
df.tail(2)
# Out:
#              order_id  order_date ship_date       ship_mode  customer_name  \
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class  Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class  Jill Matthias
#
#         segment      state        country market region  ...         category  \
# 51288  Consumer  Chihuahua         Mexico  LATAM  North  ...  Office Supplies
# 51289  Consumer   Colorado  United States     US   West  ...  Office Supplies
#
#       sub_category                            product_name sales quantity  \
# 51288       Labels  Hon Legal Exhibit Labels, Alphabetical     7        1
# 51289    Fasteners                     Bagged Rubber Bands     3        3
#
#        discount  profit  shipping_cost  order_priority  year
# 51288       0.0  0.5600           0.20          Medium  2014
# 51289       0.2 -0.6048           0.17          Medium  2014
#
# [2 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=51290, step=1)

# %%
type(df['order_date'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df[['profit','year']].head()
# Out:
#     profit  year
# 0  106.140  2011
# 1   36.036  2011
# 2   29.640  2011
# 3  -26.055  2011
# 4   37.770  2011

# %%
df[['order_id', 'product_id', 'quantity']].head()
# Out:
#           order_id        product_id  quantity
# 0     AG-2011-2040  OFF-TEN-10000025         2
# 1    IN-2011-47883   OFF-SU-10000618         3
# 2     HU-2011-1220  OFF-TEN-10001585         4
# 3  IT-2011-3647632   OFF-PA-10001492         3
# 4    IN-2011-47883   FUR-FU-10003447         5

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
type(df.dtypes == 'object')
# Out:
# pandas.core.series.Series

# %%
type(df.dtypes[df.dtypes == 'object'])
# Out:
# pandas.core.series.Series

# %%
df[df.dtypes[df.dtypes == 'object'].index].head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region        product_id  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  OFF-TEN-10000025
# 1  Consumer  New South Wales  Australia    APAC  Oceania   OFF-SU-10000618
#
#           category sub_category              product_name sales order_priority
# 0  Office Supplies      Storage       Tenex Lockers, Blue   408         Medium
# 1  Office Supplies     Supplies  Acme Trimmer, High Speed   120         Medium

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
df[df.dtypes[df.dtypes == 'float'].index].head(2)
# Out:
#    discount   profit  shipping_cost
# 0       0.0  106.140          35.46
# 1       0.1   36.036           9.72

# %%
df[df.dtypes[df.dtypes == 'int64'].index].head(2)
# Out:
#    quantity  year
# 0         2  2011
# 1         3  2011

# %%
df.order_id
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df['order_id'][1:5]
# Out:
# 1      IN-2011-47883
# 2       HU-2011-1220
# 3    IT-2011-3647632
# 4      IN-2011-47883
# Name: order_id, dtype: object

# %%
df['order_id'][1:40:2]
# Out:
# 1       IN-2011-47883
# 3     IT-2011-3647632
# 5       IN-2011-47883
# 7       IN-2011-79397
# 9        IZ-2011-4680
# 11      IN-2011-65159
# 13      IN-2011-33652
# 15     MX-2011-160234
# 17      ID-2011-80230
# 19      ID-2011-12596
# 21       IR-2011-7690
# 23       TZ-2011-7370
# 25      IN-2011-65159
# 27     MX-2011-111255
# 29     MX-2011-158771
# 31     MX-2011-111255
# 33     US-2011-136007
# 35     MX-2011-159373
# 37    IT-2011-2942451
# 39      IN-2011-33036
# Name: order_id, dtype: object

# %%
df['category1'] = 'sudh'

# %%
df['category1'].head(3)
# Out:
# 0    sudh
# 1    sudh
# 2    sudh
# Name: category1, dtype: object

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
[df['order_id'].isnull()]
# Out:
# [0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  51285    False
#  51286    False
#  51287    False
#  51288    False
#  51289    False
#  Name: order_id, Length: 51290, dtype: bool]

# %%
df99 = pd.read_csv('sales_data_final.csv')

# %%
df99.head(3)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2   HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2  Consumer         Budapest    Hungary    EMEA     EMEA  ...
#
#           category sub_category              product_name sales quantity  \
# 0  Office Supplies      Storage       Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies  Acme Trimmer, High Speed   120        3
# 2  Office Supplies      Storage   Tenex Box, Single Width    66        4
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
df['profit'].max()
# Out:
# 8399.976

# %%
df[df['profit'] == df['profit'].max()]['customer_name']
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
df[df['profit'] == df['profit'].min()]['customer_name']
# Out:
# 31884    Cindy Stewart
# Name: customer_name, dtype: object

# %%
df[df['country'] == 'Sweden'].head()
# Out:
#              order_id order_date  ship_date       ship_mode   customer_name  \
# 3     IT-2011-3647632   1/1/2011   1/5/2011    Second Class    Eugene Moren
# 168   IT-2011-5951216  1/13/2011  1/20/2011  Standard Class  Stuart Calhoun
# 477   IT-2011-5645183   2/3/2011   2/5/2011    Second Class      Max Ludwig
# 1342  IT-2011-5233011  3/31/2011   4/6/2011  Standard Class    Todd Sumrall
# 1554  IT-2011-2419493  4/12/2011  4/13/2011     First Class  Alice McCarthy
#
#           segment            state country market region  ... sub_category  \
# 3     Home Office        Stockholm  Sweden     EU  North  ...        Paper
# 168      Consumer  Vstra Gtaland  Sweden     EU  North  ...          Art
# 477   Home Office          Uppsala  Sweden     EU  North  ...          Art
# 1342    Corporate  Vstra Gtaland  Sweden     EU  North  ...  Furnishings
# 1554    Corporate        Stockholm  Sweden     EU  North  ...       Phones
#
# ...

# %%
len(df[df['country'] == 'Sweden'])
# Out:
# 203

# %%
df[df['shipping_cost'] > 80]['country'].unique()
# Out:
# array(['Australia', 'New Zealand', 'Iraq', 'Brazil', 'Mexico',
#        'United States', 'Angola', 'China', 'Hungary', 'Egypt',
#        'United Kingdom', 'Germany', 'France', 'El Salvador', 'Tanzania',
#        'Zambia', 'Nicaragua', 'Mongolia', 'Italy', 'Estonia', 'Indonesia',
#        'Cuba', 'Japan', 'South Africa', 'Morocco', 'Russia',
#        'Philippines', 'India', 'Belgium', 'Iran', 'Algeria',
#        'South Korea', 'Canada', 'Ukraine', 'Albania', 'Bangladesh',
#        'Saudi Arabia', 'Vietnam', 'Colombia',
#        'Democratic Republic of the Congo', 'Spain', 'Guinea', 'Honduras',
#        'Senegal', 'Lesotho', 'Austria', 'Romania', 'Netherlands',
#        'Malaysia', 'Ireland', 'Pakistan', 'Turkey', 'Azerbaijan',
#        'Sweden', 'Venezuela', 'Cameroon', 'Dominican Republic', 'Nigeria',
#        'Guatemala', 'Lebanon', "Cote d'Ivoire", 'Sudan', 'Thailand',
#        'Argentina', 'Ecuador', 'Benin', 'Myanmar (Burma)', 'Kenya',
# ...

# %%
len(df[df['shipping_cost'] > 80]['country'].unique())
# Out:
# 120

# %%
df[(df['shipping_cost'] > 80) & (df['profit'] < 10)].head()
# Out:
#             order_id order_date  ship_date       ship_mode     customer_name  \
# 8      ID-2011-80230   1/3/2011   1/9/2011  Standard Class      Ken Lonsdale
# 200  ES-2011-1374122  1/15/2011  1/18/2011     First Class      Craig Leslie
# 257   MX-2011-146584  1/21/2011  1/27/2011  Standard Class      Hunter Lopez
# 341    ID-2011-36011  1/26/2011  1/27/2011     First Class  Heather Kirkland
# 451  ES-2011-1640672   2/2/2011   2/5/2011     First Class        Ken Heidel
#
#          segment               state      country market          region  ...  \
# 8       Consumer            Auckland  New Zealand   APAC         Oceania  ...
# 200  Home Office  Nord-Pas-de-Calais       France     EU         Central  ...
# 257     Consumer             Managua    Nicaragua  LATAM         Central  ...
# 341    Corporate          Jawa Barat    Indonesia   APAC  Southeast Asia  ...
# 451    Corporate              Saxony      Germany     EU         Central  ...
#
# ...

# %%
date = pd.to_datetime(df['order_date'])

# %%
date.head()
# Out:
# 0   2011-01-01
# 1   2011-01-01
# 2   2011-01-01
# 3   2011-01-01
# 4   2011-01-01
# Name: order_date, dtype: datetime64[ns]

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['converted_order_date'] = date

# %%
df['order_date_year'] = df['converted_order_date'].dt.year

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sales  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...   408
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   120
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...    66
# 3  Home Office        Stockholm     Sweden      EU    North  ...    45
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   114
#
#   quantity discount   profit shipping_cost  order_priority  year  category1  \
# ...

# %%
df['order_date_month'] = df['converted_order_date'].dt.month

# %%
df['order_date_month'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: order_date_month, dtype: int64

# %%
df['order_date_week'] = df['converted_order_date'].dt.isocalendar().week

# %%
df['order_date_week'].head()
# Out:
# 0    52
# 1    52
# 2    52
# 3    52
# 4    52
# Name: order_date_week, dtype: UInt32

# %%
df['order_date_week1'] = df['converted_order_date'].dt.weekofyear
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_6840\1654002006.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['order_date_week1'] = df['converted_order_date'].dt.weekofyear

# %%
df[['order_date_week','order_date_week1']] #showing no of week month
# Out:
#        order_date_week  order_date_week1
# 0                   52                52
# 1                   52                52
# 2                   52                52
# 3                   52                52
# 4                   52                52
# ...                ...               ...
# 51285                1                 1
# 51286                1                 1
# 51287                1                 1
# 51288                1                 1
# 51289                1                 1
#
# [51290 rows x 2 columns]

# %%
df[df['order_date_year'] == 2014].head()
# Out:
#               order_id order_date ship_date       ship_mode  customer_name  \
# 33759  ES-2014-2774938   1/1/2014  1/3/2014    Second Class    Fred Harton
# 33760    IN-2014-47134   1/1/2014  1/5/2014  Standard Class    Kean Nguyen
# 33761  IT-2014-4810734   1/1/2014  1/3/2014    Second Class   Alan Shonely
# 33762   US-2014-105830   1/1/2014  1/3/2014     First Class   Duane Benoit
# 33763   CA-2014-160395   1/1/2014  1/7/2014  Standard Class  Kelly Lampkin
#
#          segment          state        country market   region  ...    profit  \
# 33759   Consumer  Ile-de-France         France     EU  Central  ... -111.6225
# 33760  Corporate       Victoria      Australia   APAC  Oceania  ...   46.9980
# 33761   Consumer  Ile-de-France         France     EU  Central  ...  -43.1370
# 33762   Consumer           Ohio  United States     US     East  ...  -35.2152
# 33763  Corporate         Nevada  United States     US     West  ...   53.9217
#
# ...

# %%
df['order_date_month'].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df.groupby('order_date_month')['sales'].sum()

# %%
df['ctc'] = df['shipping_cost'] + df['discount']

# %%
df[df['ctc'] == df['ctc'].max()]['product_name']
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
df.drop('ctc', axis= 1, inplace= True)

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   profit  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  106.140
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   36.036
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm     Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   37.770
#
#   shipping_cost order_priority  year category1  converted_order_date  \
# ...

# %%
df.drop(1, inplace = True)

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   profit  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  106.140
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm     Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   37.770
# 5     Consumer  New South Wales  Australia    APAC  Oceania  ...   15.342
#
#   shipping_cost order_priority  year category1  converted_order_date  \
# ...

# %%
df.loc[[2,3]]
# Out:
#           order_id order_date ship_date     ship_mode  customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011  Second Class  Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011  Second Class   Eugene Moren
#
#        segment      state  country market region  ...  profit shipping_cost  \
# 2     Consumer   Budapest  Hungary   EMEA   EMEA  ...  29.640          8.17
# 3  Home Office  Stockholm   Sweden     EU  North  ... -26.055          4.82
#
#   order_priority  year category1  converted_order_date  order_date_year  \
# 2           High  2011      sudh            2011-01-01             2011
# 3           High  2011      sudh            2011-01-01             2011
#
#    order_date_month  order_date_week order_date_week1
# 2                 1               52               52
# 3                 1               52               52
#
# [2 rows x 27 columns]

# %%
df.loc[2:10:2]
# Out:
#          order_id order_date ship_date       ship_mode    customer_name  \
# 2    HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 4   IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 6    CA-2011-1510   1/2/2011  1/6/2011  Standard Class  Magdelene Morse
# 8   ID-2011-80230   1/3/2011  1/9/2011  Standard Class     Ken Lonsdale
# 10  IN-2011-65159   1/3/2011  1/7/2011    Second Class     Larry Blacks
#
#      segment             state      country  market          region  ...  \
# 2   Consumer          Budapest      Hungary    EMEA            EMEA  ...
# 4   Consumer   New South Wales    Australia    APAC         Oceania  ...
# 6   Consumer           Ontario       Canada  Canada          Canada  ...
# 8   Consumer          Auckland  New Zealand    APAC         Oceania  ...
# 10  Consumer  National Capital  Philippines    APAC  Southeast Asia  ...
#
#       profit shipping_cost order_priority  year category1  \
# ...

# %%
df.loc[0:4, ['order_id','order_date','ship_date' ]]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
df.iloc[0:4, 0:3]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
df.iloc[1:5,3:6]
# Out:
#         ship_mode  customer_name      segment
# 2    Second Class  Annie Thurman     Consumer
# 3    Second Class   Eugene Moren  Home Office
# 4  Standard Class    Joseph Holt     Consumer
# 5  Standard Class    Joseph Holt     Consumer

# %%
df2 = df[df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')].index]

# %%
df2.head()
# Out:
#    quantity  discount   profit  shipping_cost  year  order_date_year  \
# 0         2       0.0  106.140          35.46  2011             2011
# 2         4       0.0   29.640           8.17  2011             2011
# 3         3       0.5  -26.055           4.82  2011             2011
# 4         5       0.1   37.770           4.70  2011             2011
# 5         2       0.1   15.342           1.80  2011             2011
#
#    order_date_month  order_date_week1
# 0                 1                52
# 2                 1                52
# 3                 1                52
# 4                 1                52
# 5                 1                52

# %%
df3 = df2[df2 > 100]

# %%
df3.head()
# Out:
#    quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0       NaN       NaN  106.14            NaN  2011             2011
# 2       NaN       NaN     NaN            NaN  2011             2011
# 3       NaN       NaN     NaN            NaN  2011             2011
# 4       NaN       NaN     NaN            NaN  2011             2011
# 5       NaN       NaN     NaN            NaN  2011             2011
#
#    order_date_month  order_date_week1
# 0               NaN               NaN
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN
# 5               NaN               NaN

# %%
# drop null values based on columns and rows

# %%
df3.dropna(axis= 1)
# Out:
#        year  order_date_year
# 0      2011             2011
# 2      2011             2011
# 3      2011             2011
# 4      2011             2011
# 5      2011             2011
# ...     ...              ...
# 51285  2014             2014
# 51286  2014             2014
# 51287  2014             2014
# 51288  2014             2014
# 51289  2014             2014
#
# [51289 rows x 2 columns]

# %%
df3.dropna(thresh= 3)
# Out:
#        quantity  discount   profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.140            NaN  2011             2011
# 7           NaN       NaN  110.412         125.32  2011             2011
# 8           NaN       NaN      NaN         107.10  2011             2011
# 9           NaN       NaN  253.320            NaN  2011             2011
# 12          NaN       NaN  290.430            NaN  2011             2011
# ...         ...       ...      ...            ...   ...              ...
# 51234       NaN       NaN  216.720            NaN  2014             2014
# 51236       NaN       NaN  180.240            NaN  2014             2014
# 51245       NaN       NaN  105.000            NaN  2014             2014
# 51252       NaN       NaN  166.440            NaN  2014             2014
# 51269       NaN       NaN  153.090            NaN  2014             2014
#
#        order_date_month  order_date_week1
# 0                   NaN               NaN
# ...

# %%
df3.fillna(value = 4)
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           4.0       4.0  106.14            4.0  2011             2011
# 2           4.0       4.0    4.00            4.0  2011             2011
# 3           4.0       4.0    4.00            4.0  2011             2011
# 4           4.0       4.0    4.00            4.0  2011             2011
# 5           4.0       4.0    4.00            4.0  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       4.0       4.0    4.00            4.0  2014             2014
# 51286       4.0       4.0    4.00            4.0  2014             2014
# 51287       4.0       4.0    4.00            4.0  2014             2014
# 51288       4.0       4.0    4.00            4.0  2014             2014
# 51289       4.0       4.0    4.00            4.0  2014             2014
#
#        order_date_month  order_date_week1
# 0                   4.0               4.0
# ...

# %%
df3.fillna(value = df['quantity'].mean())
# Out:
#        quantity  discount      profit  shipping_cost  year  order_date_year  \
# 0      3.476554  3.476554  106.140000       3.476554  2011             2011
# 2      3.476554  3.476554    3.476554       3.476554  2011             2011
# 3      3.476554  3.476554    3.476554       3.476554  2011             2011
# 4      3.476554  3.476554    3.476554       3.476554  2011             2011
# 5      3.476554  3.476554    3.476554       3.476554  2011             2011
# ...         ...       ...         ...            ...   ...              ...
# 51285  3.476554  3.476554    3.476554       3.476554  2014             2014
# 51286  3.476554  3.476554    3.476554       3.476554  2014             2014
# 51287  3.476554  3.476554    3.476554       3.476554  2014             2014
# 51288  3.476554  3.476554    3.476554       3.476554  2014             2014
# 51289  3.476554  3.476554    3.476554       3.476554  2014             2014
#
#        order_date_month  order_date_week1
# ...

# %%
df.groupby('year')['sales'].mean()
# Out:
# year
# 2011    251.127153
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64

# %%
df.groupby('year')['profit'].mean()
# Out:
# year
# 2011    27.665308
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
df.groupby('year')['shipping_cost'].mean()
# Out:
# year
# 2011    27.149201
# 2012    25.861329
# 2013    26.418577
# 2014    26.268197
# Name: shipping_cost, dtype: float64

# %%
df.groupby('year')['discount'].mean()
# Out:
# year
# 2011    0.148193
# 2012    0.141286
# 2013    0.140265
# 2014    0.143291
# Name: discount, dtype: float64

# %%
df.groupby('year')['quantity'].mean()
# Out:
# year
# 2011    3.494498
# 2012    3.476647
# 2013    3.488369
# 2014    3.457989
# Name: quantity, dtype: float64

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'converted_order_date', 'order_date_year',
#        'order_date_month', 'order_date_week', 'order_date_week1'],
#       dtype='object')

# %%
df[['country','market']].head()
# Out:
#      country  market
# 0    Algeria  Africa
# 2    Hungary    EMEA
# 3     Sweden      EU
# 4  Australia    APAC
# 5  Australia    APAC

# %%
df['sales'] = df.sales.str.replace(',', '').astype(int)

# %%
df.groupby('year')['quantity'].sum()
# Out:
# year
# 2011    31440
# 2012    38111
# 2013    48136
# 2014    60622
# Name: quantity, dtype: int64

# %%
df.groupby('year')['sales'].sum()
# Out:
# year
# 2011    2259391
# 2012    2677493
# 2013    3405860
# 2014    4300041
# Name: sales, dtype: int32
