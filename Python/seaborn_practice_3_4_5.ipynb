# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # catplot
# **Full signature of catplot-**
#
# ```python
# seaborn.catplot(x=None, y=None, hue=None, data=None, row=None, col=None, col_wrap=None, estimator=<function mean at 0x105c7d9e0>, ci=95, n_boot=1000, units=None, seed=None, order=None, hue_order=None, row_order=None, col_order=None, kind='strip', height=5, aspect=1, orient=None, color=None, palette=None, legend=True, legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, **kwargs)
# ```

# %%
sns.catplot(x = 'day', y = 'total_bill',  hue = 'smoker' ,data = tips)

# %%
sns.catplot(y = 'day', x = 'total_bill',  hue = 'smoker' ,data = tips)

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips,  jitter = False )

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips,  kind = 'swarm' )

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips,  kind = 'swarm', hue = 'size' )

# %%
#Changing order of days

sns.catplot(x = 'day', y = 'total_bill', data = tips,  kind = 'swarm', hue = 'size',
           order= ['Sun', 'Thur','Sat', 'Fri'])

# %%
sns.catplot(x = 'smoker', y = 'tip', data = tips, 
           order= ['No', 'Yes'])

# %% [markdown]
# # boxPlot

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'box')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'box', hue = 'sex')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'box', hue = 'sex' ,dodge = False)

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# # boxen plot

# %%
# sorting diamonds by color

sns.catplot(x = 'color', y ='price', data = diamonds.sort_values('color'), kind = 'boxen')

# %%
sns.catplot(x = 'color', y ='price', data = diamonds.sort_values('color'), kind = 'box')

# %%
sns.catplot( x = 'day', y= 'total_bill', data = tips, kind = 'boxen')

# %% [markdown]
# # violin plot

# %%
sns.catplot(x = 'total_bill', y = 'day', data = tips,  kind = 'violin', split = True)

# %%
sns.catplot(x = 'total_bill', y = 'day', data = tips,  kind = 'violin', split = True, hue = 'sex')

# %% [markdown]
# # swarm plot
# **Full signature of swarmplot**
#
# ```python
# seaborn.swarmplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)
# ```

# %%
n = sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'violin', inner = None)
sns.swarmplot(x = 'day', y = 'total_bill', data = tips, color = 'k', size= 3, ax = n.ax)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # bar plot

# %%
sns.catplot(x = 'sex', y = 'survived', data = titanic, hue = 'class', kind = 'bar')

# %%
sns.catplot( x = 'deck', data =titanic, kind= 'count', hue = 'class',palette= 'ch:0.95')

# %% [markdown]
# # point plot

# %%
sns.catplot(x = 'sex', y = 'survived', data = titanic, kind = 'point', hue = 'class')

# %% [markdown]
# ## Distribution of the Data

# %% [markdown]
# ### 1. ```distplot()```
#
# **Full signature of distplot**
#
# ```python
# seaborn.distplot(a, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None)
# ```

# %%
# generate random normal distribution points
x = np.random.randn(100)

# %%
sns.distplot(x, kde = True, hist = False, rug = False, bins = 30)
# Out:
# C:\Users\Shubham\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(x, kde = True,  rug = False, bins = 40)

# %%
sns.kdeplot(x, shade=True, cbar = True, bw_adjust=  1, cut = 0)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### 2. ```jointplot()```
#
# **Full signature of jointplot**
#
# ```python
# seaborn.jointplot(x, y, data=None, kind='scatter', stat_func=None, color=None, height=6, ratio=5, space=0.2, dropna=True, xlim=None, ylim=None, joint_kws=None, marginal_kws=None, annot_kws=None, **kwargs)
# ```

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.set()
sns.jointplot( x = 'total_bill', y = 'tip', data = tips, kind = 'hex', gridsize = 20)

# %%
sns.jointplot( x = 'total_bill', y = 'tip', data = tips, kind = 'kde', fill = True)

# %% [markdown]
# ### 3. ```kdeplot()```
#
# **Function Signature**
#
# ```python
# seaborn.kdeplot(data, data2=None, shade=False, vertical=False, kernel='gau', bw='scott', gridsize=100, cut=3, clip=None, legend=True, cumulative=False, shade_lowest=True, cbar=False, cbar_ax=None, cbar_kws=None, ax=None, **kwargs)
# ```

# %%
f, ax = plt.subplots(figsize =(6,6))

cmap = sns.cubehelix_palette(as_cmap= True, dark= 0, light= 1 ,reverse= True)

sns.kdeplot(x ='total_bill', y = 'tip', data = tips, cmap= cmap, n_levels = 100, shade = True, fill= True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
g = sns.jointplot(x = 'total_bill', y= 'tip', data = tips, kind = 'kde', color= 'm', fill = True)
g.plot_joint(plt.scatter, c= 'r', s= 30, linewidth = 1, marker= '+')

g.ax_joint.collections[0].set_alpha(0)

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### 4. ```pairplot()```
#
# **Function signature**
#
# ```python
# seaborn.pairplot(data, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, corner=False, dropna=True, plot_kws=None, diag_kws=None, grid_kws=None, size=None)
# ```

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels = 10)

# %% [markdown]
# ## Linear Regression and Relationship

# %% [markdown]
# ### 1. ```regplot()```
#
# **Function signrature**
#
# ```python
# seaborn.regplot(x, y, data=None, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, seed=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=True, dropna=True, x_jitter=None, y_jitter=None, label=None, color=None, marker='o', scatter_kws=None, line_kws=None, ax=None)
# ```

# %%
sns.regplot(x = 'total_bill', y ='tip', data= tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 2. ```lmplot()```
#
# **Function signature**
#
# ```python
# seaborn.lmplot(x, y, data, hue=None, col=None, row=None, palette=None, col_wrap=None, height=5, aspect=1, markers='o', sharex=True, sharey=True, hue_order=None, col_order=None, row_order=None, legend=True, legend_out=True, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, seed=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=True, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None, size=None)
# ```

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data =tips)

# %%
sns.lmplot(x = 'size', y = 'tip', data =tips, x_jitter= 0.05)

# %%
sns.lmplot(x = 'size', y = 'tip', data =tips, x_estimator= np.mean)

# %%
ansc = sns.load_dataset('anscombe')
ansc.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
ansc['dataset'].value_counts()
# Out:
# I      11
# II     11
# III    11
# IV     11
# Name: dataset, dtype: int64

# %%
sns.lmplot(x = 'x', y = 'y', data = ansc.query("dataset == 'I'"), ci = None, scatter_kws={'s' : 80} )

# %%
sns.lmplot(x = 'x', y = 'y', data = ansc.query("dataset == 'II'"), ci = None, scatter_kws={'s' : 80} )

# %%
sns.lmplot(x = 'x', y = 'y', data = ansc.query("dataset == 'III'"), ci = None, scatter_kws={'s' : 80} )

# %%
sns.lmplot(x = 'x', y = 'y', data = ansc.query("dataset == 'IV'"), ci = None, scatter_kws={'s' : 80} )

# %%
f, ax = plt.subplots(figsize = (10,5))
sns.regplot(x = 'total_bill', y = 'tip', data = tips, ax =ax)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x ='total_bill', y ='tip', data= tips, col='day', col_wrap= 2, height= 4)
